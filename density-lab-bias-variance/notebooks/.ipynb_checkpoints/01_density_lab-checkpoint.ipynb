# %% [markdown]
# # Density Lab: Bias, Variance v? Density Estimation
#
# Notebook n?y gi?p b?n quan s?t tr?c ti?p c?c ? t??ng: density estimation, Gaussian MLE, KDE, bandwidth, bias-variance, GMM v? curse of dimensionality.

# %% [markdown]
# ## 1. Gi?i thi?u
#
# Ta c? d? li?u m?u, nh?ng th??ng kh?ng bi?t ph?n ph?i th?t ?? sinh ra d? li?u. Density estimation l? vi?c ??c l??ng ???ng cong m?t ?? x?c su?t t? d? li?u quan s?t ???c.

# %%
from pathlib import Path

from density_lab.data_generator import generate_all_datasets
from density_lab.density_models import fit_gaussian_mle
from density_lab.plots import (
    plot_histogram_with_true_density,
    plot_gaussian_mle_fit,
    plot_kde_bandwidth_comparison,
    plot_bias_variance_experiment,
    plot_gmm_components_comparison,
    plot_curse_of_dimensionality,
)

FIGURES = Path("../figures")
FIGURES.mkdir(exist_ok=True)

datasets = generate_all_datasets(n=300, random_state=42)

# %% [markdown]
# ## 2. T?o d? li?u
#
# Ta d?ng ba dataset t?ng h?p:
#
# - Gaussian: m?t ??nh, ??i x?ng.
# - Mixture: hai Gaussian tr?n l?i, c? th? c? hai c?m.
# - Gamma: ph?n ph?i l?ch ph?i.

# %%
for name, dataset in datasets.items():
    print(name, dataset["samples"].shape, dataset["description"])
    plot_histogram_with_true_density(dataset, FIGURES / f"notebook_{name}_hist.png")

# %% [markdown]
# ## 3. Gaussian MLE
#
# Gaussian MLE ??c l??ng mean v? variance t? d? li?u. C?ch n?y r?t t?t n?u d? li?u th?t g?n Gaussian, nh?ng c? bias cao n?u d? li?u l?ch ho?c nhi?u c?m.

# %%
for name, dataset in datasets.items():
    params = fit_gaussian_mle(dataset["samples"])
    print(name, params)
    plot_gaussian_mle_fit(dataset, FIGURES / f"notebook_{name}_gaussian_mle.png")

# %% [markdown]
# ## 4. KDE v? bandwidth
#
# KDE ??t m?t bump m??t quanh m?i ?i?m d? li?u. Bandwidth nh? l?m ???ng cong b?m s?t d? li?u h?n. Bandwidth l?n l?m ???ng cong m??t h?n.

# %%
plot_kde_bandwidth_comparison(
    datasets["gaussian"],
    bandwidths=[0.1, 0.3, 0.7, 1.5, 3.0],
    save_path=FIGURES / "notebook_gaussian_kde_bandwidths.png",
)

# %% [markdown]
# ## 5. Bias - variance b?ng nhi?u train sets
#
# Ta sinh nhi?u b? train kh?c nhau t? c?ng m?t ph?n ph?i th?t. N?u bandwidth nh?, KDE thay ??i nhi?u gi?a c?c train sets. N?u bandwidth l?n, ???ng cong ?n ??nh h?n nh?ng d? qu? m??t.

# %%
plot_bias_variance_experiment(
    distribution_name="gaussian",
    bandwidths=[0.3, 1.0, 3.0],
    save_path=FIGURES / "notebook_bias_variance_kde.png",
)

# %% [markdown]
# ## 6. GMM
#
# Gaussian Mixture Model c?ng nhi?u Gaussian l?i v?i nhau. V?i d? li?u c? hai c?m, 2 components th??ng h?p l? h?n 1 component.

# %%
plot_gmm_components_comparison(
    datasets["mixture"],
    components=[1, 2, 5],
    save_path=FIGURES / "notebook_mixture_gmm_components.png",
)

# %% [markdown]
# ## 7. Curse of dimensionality
#
# Khi s? chi?u t?ng, kh?ng gian l?n r?t nhanh. D? li?u tr? n?n th?a, kho?ng c?ch gi?a c?c ?i?m k?m h?u ?ch h?n, v? density estimation tr? n?n kh? h?n.

# %%
plot_curse_of_dimensionality(FIGURES / "notebook_curse_of_dimensionality.png")

# %% [markdown]
# ## 8. K?t lu?n
#
# - Gaussian MLE t?t khi gi? ??nh Gaussian ??ng.
# - KDE linh ho?t nh?ng nh?y v?i bandwidth.
# - GMM t?t cho d? li?u nhi?u c?m.
# - D? li?u nhi?u chi?u th??ng c?n gi?m chi?u ho?c domain knowledge tr??c khi density estimation.
